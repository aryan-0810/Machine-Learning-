# %% [markdown]
# Question 1: 5-Fold Cross Validation with KNN on Iris Dataset

# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

iris = load_iris()

X = iris.data
y = iris.target

model = KNeighborsClassifier(n_neighbors=5)

scores = cross_val_score(
    model,
    X,
    y,
    cv=5
)

print("Fold Accuracies:", scores)

print("Average Accuracy:", scores.mean())
# Out:
# Fold Accuracies: [0.96666667 1.         0.93333333 0.96666667 1.        ]
# Average Accuracy: 0.9733333333333334

# %% [markdown]
# Question 2: 10-Fold Cross Validation with Decision Tre

# %%
from sklearn.datasets import load_wine
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

wine = load_wine()

X = wine.data
y = wine.target

model = DecisionTreeClassifier(
    random_state=42
)

scores = cross_val_score(
    model,
    X,
    y,
    cv=10
)

print("Accuracy of Each Fold:")

for i, score in enumerate(scores, start=1):
    print(f"Fold {i}: {score:.4f}")

print("\nAverage Accuracy:", scores.mean())
# Out:
# Accuracy of Each Fold:
# Fold 1: 0.8889
# Fold 2: 0.8889
# Fold 3: 0.6667
# Fold 4: 0.8889
# Fold 5: 0.8333
# Fold 6: 0.8333
# Fold 7: 1.0000
# Fold 8: 0.9444
# Fold 9: 0.9412
# Fold 10: 0.7647
#
# Average Accuracy: 0.865032679738562

# %% [markdown]
# Question 3: StratifiedKFold on Iris Dataset

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import StratifiedKFold
from collections import Counter

iris = load_iris()

X = iris.data
y = iris.target

skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), start=1):

    y_fold = y[test_idx]

    print(
        f"Fold {fold}:",
        Counter(y_fold)
    )
# Out:
# Fold 1: Counter({np.int64(0): 10, np.int64(1): 10, np.int64(2): 10})
# Fold 2: Counter({np.int64(0): 10, np.int64(1): 10, np.int64(2): 10})
# Fold 3: Counter({np.int64(0): 10, np.int64(1): 10, np.int64(2): 10})
# Fold 4: Counter({np.int64(0): 10, np.int64(1): 10, np.int64(2): 10})
# Fold 5: Counter({np.int64(0): 10, np.int64(1): 10, np.int64(2): 10})

# %% [markdown]
# Question 4: Compare Different CV Values

# %%
from sklearn.datasets import load_wine
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
import numpy as np

wine = load_wine()

X = wine.data
y = wine.target

model = RandomForestClassifier(
    random_state=42
)

for cv_value in [3, 5, 10]:

    scores = cross_val_score(
        model,
        X,
        y,
        cv=cv_value
    )

    print("\nCV =", cv_value)

    print("Scores:", scores)

    print(
        "Mean Accuracy:",
        np.mean(scores)
    )

    print(
        "Standard Deviation:",
        np.std(scores)
    )
# Out:
# CV = 3
# Scores: [0.96666667 0.94915254 0.98305085]
# Mean Accuracy: 0.9662900188323919
# Standard Deviation: 0.013841487627128413
#
# CV = 5
# Scores: [0.97222222 0.94444444 0.97222222 0.97142857 1.        ]
# Mean Accuracy: 0.9720634920634922
# Standard Deviation: 0.017571077268107502
#
# CV = 10
# Scores: [0.94444444 1.         0.94444444 0.94444444 1.         1.
#  1.         1.         1.         1.        ]
# Mean Accuracy: 0.9833333333333332
# Standard Deviation: 0.02545875386086579

# %% [markdown]
# Question 5: Generic Cross Validation Function

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

def evaluate_model(
    model,
    X,
    y,
    cv=5
):

    scores = cross_val_score(
        model,
        X,
        y,
        cv=cv
    )

    return {
        "Mean Accuracy": np.mean(scores),
        "Standard Deviation": np.std(scores)
    }


from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier

iris = load_iris()

X = iris.data
y = iris.target

model = RandomForestClassifier(
    random_state=42
)

results = evaluate_model(
    model,
    X,
    y,
    cv=5
)

print(results)
# Out:
# {'Mean Accuracy': np.float64(0.9666666666666668), 'Standard Deviation': np.float64(0.02108185106778919)}
