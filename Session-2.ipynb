# %% [markdown]
# Question 1
#
# Download the Spotify Top 50 Songs dataset from Kaggle and load it into a Pandas DataFrame. Use all song attributes as features and Popularity as the label.

# %%
import pandas as pd
df = pd.read_csv("spotify_top50.csv")
print(df.head())

X = df.drop("Popularity", axis=1)

y = df["Popularity"]

print("\nFeatures:")
print(X.columns.tolist())

print("\nLabel:")
print(y.name)
# Out:
#           Track Name         Artist  Popularity  Beats Per Minute  Length  \
# 0    Blinding Lights     The Weeknd          95               171  514552
# 1       Shape of You     Ed Sheeran          92                96  263105
# 2       Dance Monkey    Tones and I          90                98  209438
# 3  Someone You Loved  Lewis Capaldi          89               110  182161
# 4           Rockstar    Post Malone          88               160  218147
#
#    Acousticness  Energy  Danceability
# 0            20      80          0.67
# 1             1      83          0.82
# 2             1      82          0.79
# 3            10      50          0.50
# 4            15      60          0.58
#
# Features:
# ['Track Name', 'Artist', 'Beats Per Minute', 'Length', 'Acousticness', 'Energy', 'Danceability']
#
# Label:
# Popularity

# %% [markdown]
# Question 2
#
# Split the Spotify dataset into training and testing sets using an 80:20 ratio and print the number of rows in each set.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("spotify_top50.csv")

X = df.drop("Popularity", axis=1)

y = df["Popularity"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Rows:", len(X_train))
print("Testing Rows:", len(X_test))
# Out:
# Training Rows: 8
# Testing Rows: 2

# %% [markdown]
# Question 3
#
# Train a Linear Regression model using only 5% of the data for training and 95% for testing.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("spotify_top50.csv")

X = df[["Danceability"]]

y = df["Popularity"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

model = LinearRegression()

model.fit(X_train, y_train)

train_pred = model.predict(X_train)

test_pred = model.predict(X_test)

print("Training R2 Score:", r2_score(y_train, train_pred))
print("Testing R2 Score:", r2_score(y_test, test_pred))

print("Training MSE:", mean_squared_error(y_train, train_pred))
print("Testing MSE:", mean_squared_error(y_test, test_pred))
# Out:
# Training R2 Score: 0.07604490228508776
# Testing R2 Score: -0.38055725394473616
# Training MSE: 10.726541212534059
# Testing MSE: 22.08891606311578

# %% [markdown]
# Question 4
#
# Draw or find a graph online that explains the Bias–Variance Tradeoff and describe how it affects a Zomato restaurant rating predictor app.

# %%
import matplotlib.pyplot as plt

complexity = ["Very Low", "Low", "Medium", "High", "Very High"]
bias = [9, 7, 4, 2, 1]
variance = [1, 2, 4, 7, 10]
total_error = [10, 9, 8, 9, 11]

plt.figure(figsize=(8,5))

plt.plot(complexity, bias, marker='o', label='Bias')
plt.plot(complexity, variance, marker='o', label='Variance')
plt.plot(complexity, total_error, marker='o', label='Total Error')

plt.xlabel("Model Complexity")
plt.ylabel("Error")
plt.title("Bias-Variance Tradeoff")
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# Question 5
#
# Give a real example of overfitting from an app and explain why it happens.
#
# Answer
#
# Instagram Recommendation System
#
# Suppose a user watches several cricket reels in one day. If Instagram's algorithm becomes overly dependent on this short-term behavior, it may start showing only cricket-related content and ignore the user's broader interests such as technology, fitness, or travel.
#
# This is an example of overfitting, where the recommendation system learns temporary patterns too strongly and fails to generalize to the user's overall preferences.
